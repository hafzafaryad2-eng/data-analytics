# %% [markdown]
# <a href="https://colab.research.google.com/github/hafzafaryad2-eng/data-analytics/blob/main/lab19B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "tested.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "brendan45774/test-file",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_142/3839136857.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'test-file' dataset.
# First 5 records:    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.shape
# Out:
# (418, 12)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
age_filter = df[df['Age'] > 30]
print(age_filter.head())
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 0           892         0       3                  Kelly, Mr. James    male
# 1           893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2           894         0       2         Myles, Mr. Thomas Francis    male
# 11          903         0       1        Jones, Mr. Charles Cresson    male
# 13          905         0       2              Howard, Mr. Benjamin    male
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 0   34.5      0      0  330911   7.8292   NaN        Q
# 1   47.0      1      0  363272   7.0000   NaN        S
# 2   62.0      0      0  240276   9.6875   NaN        Q
# 11  46.0      0      0     694  26.0000   NaN        S
# 13  63.0      1      0   24065  26.0000   NaN        S

# %%
female_passengers = df[df['Sex'] == 'female']
print(female_passengers.head())
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 4           896         1       3
# 6           898         1       3
# 8           900         1       3
# 12          904         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 6                            Connolly, Miss. Kate  female  30.0      0      0
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 12  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1      0
#
#      Ticket     Fare Cabin Embarked
# 1    363272   7.0000   NaN        S
# 4   3101298  12.2875   NaN        S
# 6    330972   7.6292   NaN        Q
# 8      2657   7.2292   NaN        C
# 12    21228  82.2667   B45        S

# %%
first_class = df[df['Pclass'] == 1]
print(first_class.head())
# Out:
#     PassengerId  Survived  Pclass  \
# 11          903         0       1
# 12          904         1       1
# 14          906         1       1
# 20          912         0       1
# 22          914         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                             Rothschild, Mr. Martin    male  55.0      1
# 22               Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
#
#     Parch       Ticket     Fare Cabin Embarked
# 11      0          694  26.0000   NaN        S
# 12      0        21228  82.2667   B45        S
# 14      0  W.E.P. 5734  61.1750   E31        S
# 20      0     PC 17603  59.4000   NaN        C
# 22      0     PC 17598  31.6833   NaN        S

# %%
print("Unique Sex Values:", df['Sex'].unique())
print("Unique Passenger Classes:", df['Pclass'].unique())
print("Unique Embarked Ports:", df['Embarked'].unique())

# Count distinct values
print("Embarked Value Counts:")
print(df['Embarked'].value_counts())
# Out:
# Unique Sex Values: ['male' 'female']
# Unique Passenger Classes: [3 2 1]
# Unique Embarked Ports: ['Q' 'S' 'C']
# Embarked Value Counts:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
summary = df[['Age','Fare','SibSp','Parch']].agg(['sum','max','min','count','mean','median','std'])
print(summary)
# Out:
#                  Age          Fare       SibSp       Parch
# sum     10050.500000  14856.537600  187.000000  164.000000
# max        76.000000    512.329200    8.000000    9.000000
# min         0.170000      0.000000    0.000000    0.000000
# count     332.000000    417.000000  418.000000  418.000000
# mean       30.272590     35.627188    0.447368    0.392344
# median     27.000000     14.454200    0.000000    0.000000
# std        14.181209     55.907576    0.896760    0.981429

# %%
print("Mode Values:")
print(df.mode())
# Out:
# Mode Values:
#      PassengerId  Survived  Pclass  \
# 0            892       0.0     3.0
# 1            893       NaN     NaN
# 2            894       NaN     NaN
# 3            895       NaN     NaN
# 4            896       NaN     NaN
# ..           ...       ...     ...
# 413         1305       NaN     NaN
# 414         1306       NaN     NaN
# 415         1307       NaN     NaN
# 416         1308       NaN     NaN
# 417         1309       NaN     NaN
#
#                                               Name   Sex   Age  SibSp  Parch  \
# 0                    Abbott, Master. Eugene Joseph  male  21.0    0.0    0.0
# 1                      Abelseth, Miss. Karen Marie   NaN  24.0    NaN    NaN
# 2                    Abelseth, Mr. Olaus Jorgensen   NaN   NaN    NaN    NaN
# 3         Abrahamsson, Mr. Abraham August Johannes   NaN   NaN    NaN    NaN
# 4        Abrahim, Mrs. Joseph (Sophie Halaut Easu)   NaN   NaN    NaN    NaN
# ...

# %%
print("Mode Values:")
print(df.mode().iloc[0])
# Out:
# Mode Values:
# PassengerId                              892
# Survived                                 0.0
# Pclass                                   3.0
# Name           Abbott, Master. Eugene Joseph
# Sex                                     male
# Age                                     21.0
# SibSp                                    0.0
# Parch                                    0.0
# Ticket                              PC 17608
# Fare                                    7.75
# Cabin                        B57 B59 B63 B66
# Embarked                                   S
# Name: 0, dtype: object

# %%
age_by_gender = df.groupby('Sex')['Age'].mean()
print(age_by_gender)
# Out:
# Sex
# female    30.272362
# male      30.272732
# Name: Age, dtype: float64

# %%
fare_by_class = df.groupby('Pclass')['Fare'].agg(['sum','max','min','mean','median','std'])
print(fare_by_class)
# Out:
#                sum       max     min       mean   median        std
# Pclass
# 1       10087.9918  512.3292  0.0000  94.280297  60.0000  84.435858
# 2        2064.7957   73.5000  9.6875  22.202104  15.7500  13.991877
# 3        2703.7501   69.5500  3.1708  12.459678   7.8958  10.803698

# %%
gender_count = df.groupby('Sex')['PassengerId'].count()
print(gender_count)
# Out:
# Sex
# female    152
# male      266
# Name: PassengerId, dtype: int64

# %%
# kde stands for kernal density estimate and used to show curve over bars and bins is intervals between counts , the less the bins values more detailed graph is like more bins more detailed
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title("Age Distribution of Passengers")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Pclass', data=df)
plt.title("Passenger Class Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Sex', data=df)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title("Fare Distribution by Passenger Class")
plt.show()

# %%
print("""
Insights:

1. Most passengers belong to 3rd class, showing that lower-class passengers formed the majority.
2. The average fare of 1st class passengers is significantly higher than 2nd and 3rd class.
3. The dataset contains more male passengers than female passengers.
4. The age distribution shows that most passengers were between 20 and 40 years old.
5. Some missing values exist in Age and Cabin columns.
6. Passengers traveling in higher classes generally paid higher fares.
""")
# Out:
# Insights:
#
# 1. Most passengers belong to 3rd class, showing that lower-class passengers formed the majority.
# 2. The average fare of 1st class passengers is significantly higher than 2nd and 3rd class.
# 3. The dataset contains more male passengers than female passengers.
# 4. The age distribution shows that most passengers were between 20 and 40 years old.
# 5. Some missing values exist in Age and Cabin columns.
# 6. Passengers traveling in higher classes generally paid higher fares.

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "Superstore.csv"

# Load the latest version
df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "ishanshrivastava28/superstore-sales",
  file_path,
  pandas_kwargs={'encoding': 'latin1'}
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# Using Colab cache for faster access to the 'superstore-sales' dataset.
# First 5 records:    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "weather.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "codingelements/weather",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_400/837062985.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ...
# 100%|██████████| 11.7k/11.7k [00:00<00:00, 16.0MB/s]
# First 5 records:    year  month element       day1       day2       day3       day4       day5  \
# 0  2018      1     max  17.573016  19.796815  22.412495  17.813163  20.165825
# 1  2018      1     min  22.725760  21.007865  17.730792  18.045290  20.766734
# 2  2018      2     max  19.015120  19.261805  17.510713  21.080425  17.915749
# 3  2018      2     min  18.653843  22.818600  21.842673  21.958159  22.523078
# 4  2018      3     max  20.741115  19.704016  17.039811  20.703908  22.714125
#
#         day6       day7  ...      day22      day23      day24      day25  \
# 0  17.060539  22.736134  ...  22.629226  19.013674  17.831558  17.018316
# 1  18.656651  22.607481  ...  21.163491  17.371653  17.194530  18.964190
# ...

# %%
df.head()
# Out:
#    year  month element       day1       day2       day3       day4       day5  \
# 0  2018      1     max  17.573016  19.796815  22.412495  17.813163  20.165825
# 1  2018      1     min  22.725760  21.007865  17.730792  18.045290  20.766734
# 2  2018      2     max  19.015120  19.261805  17.510713  21.080425  17.915749
# 3  2018      2     min  18.653843  22.818600  21.842673  21.958159  22.523078
# 4  2018      3     max  20.741115  19.704016  17.039811  20.703908  22.714125
#
#         day6       day7  ...      day22      day23      day24      day25  \
# 0  17.060539  22.736134  ...  22.629226  19.013674  17.831558  17.018316
# 1  18.656651  22.607481  ...  21.163491  17.371653  17.194530  18.964190
# 2  19.082145  18.056023  ...  21.254968  20.346324  20.036019  22.926773
# 3  18.535469  19.636158  ...  19.711974  20.586232  18.780840  20.065633
# 4  17.205000  19.079503  ...  19.528963  19.563689  22.658997  22.446357
#
# ...

# %%
df.shape
# Out:
# (22, 34)

# %%
df.columns
# Out:
# Index(['year', 'month', 'element', 'day1', 'day2', 'day3', 'day4', 'day5',
#        'day6', 'day7', 'day8', 'day9', 'day10', 'day11', 'day12', 'day13',
#        'day14', 'day15', 'day16', 'day17', 'day18', 'day19', 'day20', 'day21',
#        'day22', 'day23', 'day24', 'day25', 'day26', 'day27', 'day28', 'day29',
#        'day30', 'day31'],
#       dtype='object')

# %%
df.describe()
# Out:
#          year      month       day1       day2       day3       day4  \
# count    22.0  22.000000  22.000000  22.000000  22.000000  22.000000
# mean   2018.0   6.272727  19.932125  20.285438  20.309974  20.164147
# std       0.0   3.601347   1.864194   1.167673   2.173108   1.733833
# min    2018.0   1.000000  17.250431  18.287267  17.039811  17.359855
# 25%    2018.0   3.250000  18.540946  19.549007  17.800475  18.459219
# 50%    2018.0   6.000000  19.359951  20.224575  21.316994  20.380124
# 75%    2018.0   9.500000  21.640831  20.958645  22.180151  21.689389
# max    2018.0  12.000000  22.845420  22.818600  22.745302  22.810337
#
#             day5       day6       day7       day8  ...      day22      day23  \
# count  22.000000  22.000000  22.000000  22.000000  ...  22.000000  22.000000
# mean   20.167074  19.193425  20.249531  20.341465  ...  20.023471  20.158556
# std     1.808135   1.596474   1.662390   1.551153  ...   1.721108   1.718532
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 34 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     22 non-null     int64
#  1   month    22 non-null     int64
#  2   element  22 non-null     object
#  3   day1     22 non-null     float64
#  4   day2     22 non-null     float64
#  5   day3     22 non-null     float64
#  6   day4     22 non-null     float64
#  7   day5     22 non-null     float64
#  8   day6     22 non-null     float64
#  9   day7     22 non-null     float64
#  10  day8     22 non-null     float64
#  11  day9     22 non-null     float64
#  12  day10    22 non-null     float64
#  13  day11    22 non-null     float64
#  14  day12    22 non-null     float64
#  15  day13    22 non-null     float64
#  16  day14    22 non-null     float64
#  17  day15    22 non-null     float64
#  18  day16    22 non-null     float64
#  19  day17    22 non-null     float64
# ...

# %%
max_temp = df[df["element"] == "max"]

max_temp.head()
# Out:
#    year  month element       day1       day2       day3       day4       day5  \
# 0  2018      1     max  17.573016  19.796815  22.412495  17.813163  20.165825
# 2  2018      2     max  19.015120  19.261805  17.510713  21.080425  17.915749
# 4  2018      3     max  20.741115  19.704016  17.039811  20.703908  22.714125
# 6  2018      4     max  20.408029  21.634346  22.677863  20.839558  19.371399
# 8  2018      5     max  21.354089  21.806705  19.863229  22.475220  18.996700
#
#         day6       day7  ...      day22      day23      day24      day25  \
# 0  17.060539  22.736134  ...  22.629226  19.013674  17.831558  17.018316
# 2  19.082145  18.056023  ...  21.254968  20.346324  20.036019  22.926773
# 4  17.205000  19.079503  ...  19.528963  19.563689  22.658997  22.446357
# 6  18.202578  21.916666  ...  18.086580  21.861976  22.605832  19.209812
# 8  20.851806  18.774501  ...  20.509023  20.080743  22.593543  18.806516
#
# ...

# %%
weather_2018 = df[df["year"] == 2018]

weather_2018.head()
# Out:
#    year  month element       day1       day2       day3       day4       day5  \
# 0  2018      1     max  17.573016  19.796815  22.412495  17.813163  20.165825
# 1  2018      1     min  22.725760  21.007865  17.730792  18.045290  20.766734
# 2  2018      2     max  19.015120  19.261805  17.510713  21.080425  17.915749
# 3  2018      2     min  18.653843  22.818600  21.842673  21.958159  22.523078
# 4  2018      3     max  20.741115  19.704016  17.039811  20.703908  22.714125
#
#         day6       day7  ...      day22      day23      day24      day25  \
# 0  17.060539  22.736134  ...  22.629226  19.013674  17.831558  17.018316
# 1  18.656651  22.607481  ...  21.163491  17.371653  17.194530  18.964190
# 2  19.082145  18.056023  ...  21.254968  20.346324  20.036019  22.926773
# 3  18.535469  19.636158  ...  19.711974  20.586232  18.780840  20.065633
# 4  17.205000  19.079503  ...  19.528963  19.563689  22.658997  22.446357
#
# ...

# %%
print("Unique Years:")
print(df["year"].unique())

print("\nUnique Months:")
print(df["month"].unique())

print("\nTemperature Types:")
print(df["element"].unique())
# Out:
# Unique Years:
# [2018]
#
# Unique Months:
# [ 1  2  3  4  5  6  7  8 10 11 12]
#
# Temperature Types:
# ['max' 'min']

# %%
df["day1"].agg(["sum","max","min","count","mean","median","std"])
# Out:
# sum       438.506757
# max        22.845420
# min        17.250431
# count      22.000000
# mean       19.932125
# median     19.359951
# std         1.864194
# Name: day1, dtype: float64

# %%
df["day1"].mode()
# Out:
# 0     17.250431
# 1     17.367511
# 2     17.573016
# 3     17.994997
# 4     18.175223
# 5     18.503314
# 6     18.653843
# 7     18.889095
# 8     18.896222
# 9     19.006195
# 10    19.015120
# 11    19.704782
# 12    20.408029
# 13    20.741115
# 14    21.121687
# 15    21.354089
# 16    21.736412
# 17    21.849449
# 18    22.275672
# 19    22.419377
# 20    22.725760
# 21    22.845420
# Name: day1, dtype: float64

# %%
df.groupby("element")["day1"].mean()
# Out:
# element
# max    19.647198
# min    20.217053
# Name: day1, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df["day1"])

plt.title("Temperature Distribution (Day1)")

plt.show()

# %%
df.groupby("element")["day1"].mean().plot(kind="bar")

plt.title("Average Temperature by Type")

plt.xlabel("Temperature Type")
plt.ylabel("Average Temperature")

plt.show()

# %%
sns.boxplot(x=df["day1"])

plt.title("Temperature Spread for Day1")

plt.show()

# %% [markdown]
# nterpretation 1
#
# The mean temperature shows the average weather conditions for the dataset.
#
# Interpretation 2
#
# The difference between mean and median indicates whether temperature values are evenly distributed or affected by extreme values.
#
# Interpretation 3
#
# The histogram shows that most temperatures fall within a certain range, indicating typical weather patterns.
#
# Interpretation 4
#
# The bar chart comparison between max and min temperatures shows the daily temperature variation.

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "netflix_titles.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "omk787/netflix-titles",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_400/190740185.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ...
# 100%|██████████| 971k/971k [00:00<00:00, 78.2MB/s]
# Extracting zip of netflix_titles.csv...
# First 5 records:     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# ...

# %%
df.head(10)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
# 5  80163890  TV Show                                  Apaches
# 6  70304989    Movie                                 Automata
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 8  80117902  TV Show                             Fire Chasers
# 9  70304990    Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# ...

# %%
df.describe()
# Out:
#             show_id  release_year
# count  6.234000e+03    6234.00000
# mean   7.670368e+07    2013.35932
# std    1.094296e+07       8.81162
# min    2.477470e+05    1925.00000
# 25%    8.003580e+07    2013.00000
# 50%    8.016337e+07    2016.00000
# 75%    8.024489e+07    2018.00000
# max    8.123573e+07    2020.00000

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.shape
# Out:
# (6234, 12)

# %%
movies = df[df["type"] == "Movie"]

movies.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
# 4  80125979  Movie                             #realityhigh
# 6  70304989  Movie                                 Automata
# 7  80164077  Movie       Fabrizio Copano: Solo pienso en mi
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 4                 Fernando Lebrija
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                    Fabrizio Copano
#
# ...

# %%
tvshows = df[df["type"] == "TV Show"]

tvshows.head()
# Out:
#      show_id     type                             title director  \
# 2   70234439  TV Show                Transformers Prime      NaN
# 3   80058654  TV Show  Transformers: Robots in Disguise      NaN
# 5   80163890  TV Show                           Apaches      NaN
# 8   80117902  TV Show                      Fire Chasers      NaN
# 26  80244601  TV Show                   Castle of Stars      NaN
#
#                                                  cast        country  \
# 2   Peter Cullen, Sumalee Montano, Frank Welker, J...  United States
# 3   Will Friedle, Darren Criss, Constance Zimmer, ...  United States
# 5   Alberto Ammann, Eloy Azorín, Verónica Echegui,...          Spain
# 8                                                 NaN  United States
# 26  Chaiyapol Pupart, Jintanutda Lummakanon, Worra...            NaN
#
#            date_added  release_year    rating  duration  \
# 2   September 8, 2018          2013  TV-Y7-FV  1 Season
# ...

# %%
recent_shows = df[df["release_year"] > 2018]

recent_shows.head()
# Out:
#      show_id     type                                    title  \
# 0   81145628    Movie  Norm of the North: King Sized Adventure
# 34  80221550  TV Show               Archibald's Next Big Thing
# 35  81154455    Movie                               Article 15
# 38  81132437    Movie                      Kill Me If You Dare
# 39  80178151  TV Show                                  The Spy
#
#                     director  \
# 0   Richard Finn, Tim Maltby
# 34                       NaN
# 35             Anubhav Sinha
# 38              Şenol Sönmez
# 39                       NaN
#
#                                                  cast  \
# 0   Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 34  Tony Hale, Rosamund Pike, Jordan Fisher, Chels...
# 35  Ayushmann Khurrana, Nassar, Manoj Pahwa, Kumud...
# 38  Murat Boz, Seda Bakan, Açelya Topaloğlu, Özgür...
# 39  Sacha Baron Cohen, Noah Emmerich, Hadar Ratzon...
#
# ...

# %%
print("Unique Types:")
print(df["type"].unique())

print("\nUnique Ratings:")
print(df["rating"].unique())

#\n is a newline character in Python.
#It tells Python to start printing from a new line.

print("\nUnique Countries:")
print(df["country"].unique())
# Out:
# Unique Types:
# ['Movie' 'TV Show']
#
# Unique Ratings:
# ['TV-PG' 'TV-MA' 'TV-Y7-FV' 'TV-Y7' 'TV-14' 'R' 'TV-Y' 'NR' 'PG-13' 'TV-G'
#  'PG' 'G' nan 'UR' 'NC-17']
#
# Unique Countries:
# ['United States, India, South Korea, China' 'United Kingdom'
#  'United States' 'Spain' 'Bulgaria, United States, Spain, Canada' 'Chile'
#  'United States, United Kingdom, Denmark, Sweden' nan
#  'Netherlands, Belgium, United Kingdom, United States' 'France, Belgium'
#  'United States, Uruguay' 'United States,' 'Thailand'
#  'China, Canada, United States' 'Belgium, United Kingdom, United States'
#  'Belgium, France' 'India' 'France' 'United States, Canada' 'Pakistan'
#  'Canada' 'United Kingdom, France' 'United States, United Kingdom'
#  'South Korea' 'Denmark, United States' 'United Kingdom, United States'
#  'Turkey, United States' 'Brazil'
#  'Denmark, France, Italy, Belgium, Netherlands' 'Indonesia' 'China'
#  'Ireland, United Kingdom' 'Turkey' 'Hong Kong' 'France, Morocco'
# ...

# %%
df["release_year"].agg(["sum","max","min","count","mean","median","std"])
# Out:
# sum       1.255128e+07
# max       2.020000e+03
# min       1.925000e+03
# count     6.234000e+03
# mean      2.013359e+03
# median    2.016000e+03
# std       8.811620e+00
# Name: release_year, dtype: float64

# %%
df["release_year"].mode()
# Out:
# 0    2018
# Name: release_year, dtype: int64

# %%
df.groupby("type")["show_id"].count()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: show_id, dtype: int64

# %%
df.groupby("type")["release_year"].mean()
# Out:
# type
# Movie      2012.354279
# TV Show    2015.536313
# Name: release_year, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x="type", data=df)

plt.title("Number of Movies vs TV Shows")

plt.show()

# %%
sns.histplot(df["release_year"], bins=20)

plt.title("Distribution of Release Years")

plt.show()

# %%
sns.boxplot(x=df["release_year"])

plt.title("Spread of Release Years")

plt.show()

# %% [markdown]
# Insight 1
#
# Most of the titles on Netflix are movies compared to TV shows.
#
# Insight 2
#
# The average release year indicates that most content on Netflix is relatively recent.
#
# Insight 3
#
# The histogram shows that a large number of titles were released after 2015, indicating Netflix focuses on newer content.
#
# Insight 4
#
# The bar chart highlights the dominance of movies over TV shows in the dataset.

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "student_performance.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "navneetkaurbrarr/student-performance",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_400/1184585197.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ...
# 100%|██████████| 12.0k/12.0k [00:00<00:00, 18.2MB/s]
# First 5 records:    Student_ID       Name  Math_Score  Science_Score  English_Score
# 0           1  Student_1          58             51             57
# 1           2  Student_2          89             51             88
# 2           3  Student_3          81             55             60
# 3           4  Student_4          96             78             79
# 4           5  Student_5          40             73             75

# %%
df.head(10)
# Out:
#    Student_ID        Name  Math_Score  Science_Score  English_Score
# 0           1   Student_1          58             51             57
# 1           2   Student_2          89             51             88
# 2           3   Student_3          81             55             60
# 3           4   Student_4          96             78             79
# 4           5   Student_5          40             73             75
# 5           6   Student_6          83             64             79
# 6           7   Student_7          53             63             47
# 7           8   Student_8          86             68             65
# 8           9   Student_9          71             61             49
# 9          10  Student_10          82             79             92

# %%
math_score=df[df['Math_Score']>80]
math_score.head()
# Out:
#    Student_ID       Name  Math_Score  Science_Score  English_Score
# 1           2  Student_2          89             51             88
# 2           3  Student_3          81             55             60
# 3           4  Student_4          96             78             79
# 5           6  Student_6          83             64             79
# 7           8  Student_8          86             68             65

# %%
print('unique name')
print(df['Name'].unique())
# Out:
# unique name
# ['Student_1' 'Student_2' 'Student_3' 'Student_4' 'Student_5' 'Student_6'
#  'Student_7' 'Student_8' 'Student_9' 'Student_10' 'Student_11'
#  'Student_12' 'Student_13' 'Student_14' 'Student_15' 'Student_16'
#  'Student_17' 'Student_18' 'Student_19' 'Student_20' 'Student_21'
#  'Student_22' 'Student_23' 'Student_24' 'Student_25' 'Student_26'
#  'Student_27' 'Student_28' 'Student_29' 'Student_30' 'Student_31'
#  'Student_32' 'Student_33' 'Student_34' 'Student_35' 'Student_36'
#  'Student_37' 'Student_38' 'Student_39' 'Student_40' 'Student_41'
#  'Student_42' 'Student_43' 'Student_44' 'Student_45' 'Student_46'
#  'Student_47' 'Student_48' 'Student_49' 'Student_50' 'Student_51'
#  'Student_52' 'Student_53' 'Student_54' 'Student_55' 'Student_56'
#  'Student_57' 'Student_58' 'Student_59' 'Student_60' 'Student_61'
#  'Student_62' 'Student_63' 'Student_64' 'Student_65' 'Student_66'
#  'Student_67' 'Student_68' 'Student_69' 'Student_70' 'Student_71'
# ...

# %%
summary_stats = df['Math_Score'].agg(['sum','mean','median','min','max','count','std'])
summary_stats['mode'] = df['Math_Score'].mode().iloc[0] # Taking the first mode value
print(summary_stats)
# Out:
# sum       34538.000000
# mean         69.076000
# median       68.000000
# min          40.000000
# max          99.000000
# count       500.000000
# std          17.353862
# mode         66.000000
# Name: Math_Score, dtype: float64

# %%
df.groupby("Math_Score")["Student_ID"].count()
# Out:
# Math_Score
# 40    13
# 41     7
# 42    11
# 43     7
# 44    10
# 45     6
# 46     5
# 47    11
# 48     7
# 49    11
# 50     7
# 51     5
# 52     7
# 53     7
# 54    10
# 55    11
# 56     7
# 57     6
# 58    10
# 59     9
# 60    10
# 61    10
# 62    10
# 63    12
# 64     6
# 65     7
# 66    14
# 67     9
# 68    10
# 69     8
# 70     9
# 71     6
# 72     9
# 73     6
# 74     5
# 75     9
# 76     5
# 77     5
# 78     5
# 79    10
# 80     7
# 81     7
# 82    13
# 83     5
# 84     9
# 85    11
# 86    10
# 87     6
# 88    14
# 89     8
# 90    11
# 91     5
# 92     7
# 93     6
# 94     7
# 95    11
# 96     8
# 97    11
# 98     8
# 99     4
# Name: Student_ID, dtype: int64

# %%
df.groupby("Student_ID")["English_Score"].mean()
# Out:
# Student_ID
# 1      57.0
# 2      88.0
# 3      60.0
# 4      79.0
# 5      75.0
#        ...
# 496    98.0
# 497    98.0
# 498    91.0
# 499    64.0
# 500    50.0
# Name: English_Score, Length: 500, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x="Math_Score", data=df)

plt.title("maths students")

plt.show()

# %%
sns.histplot(df["Math_Score"], bins=10)

plt.title("Distribution of Math Scores")
plt.xlabel("Math Score")
plt.ylabel("Frequency")

plt.show()

# %%
sns.histplot(df["Science_Score"], bins=15)
plt.title("Distribution of Science Scores")
plt.show()

# %%
sns.histplot(df["English_Score"], bins=15)
plt.title("Distribution of English Scores")
plt.show()

# %%
avg_scores = df[["Math_Score","Science_Score","English_Score"]].mean()

avg_scores.plot(kind="bar")

plt.title("Average Scores by Subject")
plt.xlabel("Subjects")
plt.ylabel("Average Score")

plt.show()

# %%
sns.boxplot(data=df[["Math_Score","Science_Score","English_Score"]])

plt.title("Score Distribution by Subject")

plt.show()

# %%
plt.scatter(df["Math_Score"], df["Science_Score"])

plt.title("Math vs Science Scores")
plt.xlabel("Math Score")
plt.ylabel("Science Score")

plt.show()

# %%
corr = df[["Math_Score","Science_Score","English_Score"]].corr()

sns.heatmap(corr, annot=True)

plt.title("Correlation Between Subjects")

plt.show()

# %% [markdown]
# Insight 1
#
# The histogram shows how student scores are distributed across subjects.
#
# Insight 2
#
# The bar chart indicates which subject has the highest average score among students.
#
# Insight 3
#
# The boxplot reveals score variability and potential outliers in the dataset.
#
# Insight 4
#
# The scatter plot suggests whether performance in one subject is related to another.
#
# Insight 5
#
# The heatmap helps identify correlations between math, science, and English scores.

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "AAPL.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "liamhealy/asset-returns",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_533/124624713.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ...
# 100%|██████████| 18.4k/18.4k [00:00<00:00, 19.6MB/s]
# First 5 records:          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-12-22  134.350006  134.559998  130.300003  132.229996  131.494995
# 1  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.127075
# 2  2022-12-27  131.380005  131.410004  128.720001  130.029999  129.307220
# 3  2022-12-28  129.669998  131.029999  125.870003  126.040001  125.339417
# 4  2022-12-29  127.989998  130.479996  127.730003  129.610001  128.889557
#
#      Volume
# 0  77852100
# 1  63814900
# 2  69007800
# 3  85438400
# 4  75703700

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-12-22  134.350006  134.559998  130.300003  132.229996  131.494995
# 1  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.127075
# 2  2022-12-27  131.380005  131.410004  128.720001  130.029999  129.307220
# 3  2022-12-28  129.669998  131.029999  125.870003  126.040001  125.339417
# 4  2022-12-29  127.989998  130.479996  127.730003  129.610001  128.889557
#
#      Volume
# 0  77852100
# 1  63814900
# 2  69007800
# 3  85438400
# 4  75703700

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
high_volume=df[df['Volume']>700000]
high_volume.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-12-22  134.350006  134.559998  130.300003  132.229996  131.494995
# 1  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.127075
# 2  2022-12-27  131.380005  131.410004  128.720001  130.029999  129.307220
# 3  2022-12-28  129.669998  131.029999  125.870003  126.040001  125.339417
# 4  2022-12-29  127.989998  130.479996  127.730003  129.610001  128.889557
#
#      Volume
# 0  77852100
# 1  63814900
# 2  69007800
# 3  85438400
# 4  75703700

# %%
high_price = df[df["High"] > 135]

high_price.head()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 15  2023-01-17  134.830002  137.289993  134.130005  135.940002  135.184387
# 16  2023-01-18  136.820007  138.610001  135.029999  135.210007  134.458450
# 17  2023-01-19  134.080002  136.250000  133.770004  135.270004  134.518112
# 18  2023-01-20  135.279999  138.020004  134.220001  137.869995  137.103653
# 19  2023-01-23  138.119995  143.320007  137.899994  141.110001  140.325653
#
#       Volume
# 15  63646600
# 16  69672800
# 17  58280400
# 18  80223600
# 19  81760300

# %%
print(df["Volume"].unique())
# Out:
# [ 77852100  63814900  69007800  85438400  75703700  77034200 112117500
#   89113600  80962700  87754700  70790800  63896200  69458900  71379600
#   57809700  63646600  69672800  58280400  80223600  81760300  66435100
#   65799300  54105100  70555800  64015300  65874500  77663600 118339000
#  154357300  69858300  83322600  64120100  56007100  57450700  62199000
#   61707600  65573800  68167900  59144100  58867200  51011300  48394200
#   55469600  44998500  50547000  55479000  52238100  70732300  87558000
#   56182000  47204800  53833600  68572400  84457100  73695900  77167900
#   76161100  98944600  73641400  73938300  75701800  67622100  59196500
#   52390300  45992200  51305700  49501700  68749800  56976200  46278300
#   51511700  45390100  47716900  47644200  50133100  68445600  49386500
#   41516200  49923000  47720200  52456400  58337300  41949600  48714100
#   45498800  64902300  55209200  52472900  48425700  65136000  81235400
# ...

# %%
print(df["Date"].unique())
# Out:
# ['2022-12-22' '2022-12-23' '2022-12-27' '2022-12-28' '2022-12-29'
#  '2022-12-30' '2023-01-03' '2023-01-04' '2023-01-05' '2023-01-06'
#  '2023-01-09' '2023-01-10' '2023-01-11' '2023-01-12' '2023-01-13'
#  '2023-01-17' '2023-01-18' '2023-01-19' '2023-01-20' '2023-01-23'
#  '2023-01-24' '2023-01-25' '2023-01-26' '2023-01-27' '2023-01-30'
#  '2023-01-31' '2023-02-01' '2023-02-02' '2023-02-03' '2023-02-06'
#  '2023-02-07' '2023-02-08' '2023-02-09' '2023-02-10' '2023-02-13'
#  '2023-02-14' '2023-02-15' '2023-02-16' '2023-02-17' '2023-02-21'
#  '2023-02-22' '2023-02-23' '2023-02-24' '2023-02-27' '2023-02-28'
#  '2023-03-01' '2023-03-02' '2023-03-03' '2023-03-06' '2023-03-07'
#  '2023-03-08' '2023-03-09' '2023-03-10' '2023-03-13' '2023-03-14'
#  '2023-03-15' '2023-03-16' '2023-03-17' '2023-03-20' '2023-03-21'
#  '2023-03-22' '2023-03-23' '2023-03-24' '2023-03-27' '2023-03-28'
#  '2023-03-29' '2023-03-30' '2023-03-31' '2023-04-03' '2023-04-04'
# ...

# %%
df["Close"].agg(["sum","max","min","count","mean","median","std"])
# Out:
# sum       42951.040067
# max         198.110001
# min         125.019997
# count       251.000000
# mean        171.119682
# median      174.910004
# std          18.228162
# Name: Close, dtype: float64

# %%
df["Close"].mode()
# Out:
# 0    163.759995
# 1    172.070007
# 2    173.750000
# 3    175.839996
# 4    177.970001
# 5    178.850006
# 6    179.800003
# Name: Close, dtype: float64

# %%
#only want first mode of that columns
df["Close"].mode()[0]
# Out:
# np.float64(163.759995)

# %%
df["Date"] = pd.to_datetime(df["Date"])

df["Month"] = df["Date"].dt.month

# %%
df.groupby("Month")["Close"].mean()
# Out:
# Month
# 1     135.778999
# 2     150.968421
# 3     154.964782
# 4     165.045790
# 5     172.622728
# 6     184.283333
# 7     192.411501
# 8     181.083913
# 9     177.002501
# 10    174.668638
# 11    185.879523
# 12    176.188572
# Name: Close, dtype: float64

# %%
plt.figure(figsize=(10,5))

plt.plot(df["Date"], df["Close"])

plt.title("Apple Stock Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price")

plt.show()

# %%
sns.histplot(df["Close"], bins=20)

plt.title("Distribution of Closing Prices")

plt.show()

# %%
sns.boxplot(x=df["Close"])

plt.title("Spread of Closing Prices")

plt.show()

# %%
plt.scatter(df["Open"], df["Close"])

plt.title("Open Price vs Close Price")
plt.xlabel("Open Price")
plt.ylabel("Close Price")

plt.show()

# %% [markdown]
# Insight 1
#
# The line chart shows the trend of Apple stock closing prices over time.
#
# Insight 2
#
# The histogram shows that most closing prices fall within a specific range.
#
# Insight 3
#
# The boxplot helps identify any unusually high or low stock prices.
#
# Insight 4
#
# The scatter plot shows the relationship between opening and closing stock prices.
